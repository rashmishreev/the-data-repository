# %% [markdown]
# ## Informative and attractive visualizations in Python using the Seaborn library

# %% [markdown]
# **Seaborn**
# - Seaborn is a powerful Python library that makes it easy to create informative and attractive data visualizations.
# - Data visualization is often a huge component of both the data exploration phase and the communication of results, so Seaborn is very useful.
# -  We can use Seaborn to create a variety of plots, including scatter plots, count plots, bar plots, and box plots, and can also customize visualizations.
#
#
# **Advantages**
# - Seaborn's main purpose is to make data visualization easy. It was built to automatically handle a lot of complexity behind the scenes.
# - Works extremely well with pandas data structures. pandas is a Python library that is widely used for data analysis.
# - It's built on top of Matplotlib, which is another Python visualization library. Matplotlib is extremely flexible. Seaborn allows to take advantage of this flexibility when needed, while avoiding the complexity that Matplotlib's flexibility can introduce.
#
# **Importing Seaborn Library**
# - The line "`import seaborn as sns`" will import Seaborn as the conventionally used alias "`sns`".
# - "`sns`"?: The Seaborn library was apparently named after a character named *Samuel Norman Seaborn* from the television show "The West Wing" - thus, the standard alias is the character's initials.
# - Also need to import Matplotlib, which is the library that Seaborn is built on top of. "`import matplotlib.pyplot as plt`". "`plt`" is the alias that most people use to refer to Matplotlib, so we'll use that here as well.

# %%
# Importing the seaborn and matplotlib libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ```python
# Seaborn plot types
#
# 1. sns.scatterplot()
# 2. sns.countplot()
# 3. sns.relplot()
# 4. sns.barplot()
# 5. sns.catplot()
# ```

# %% [markdown]
# ```python
# Parameters
# x = 'column_on_x_axis'
# y = 'column_on_y_axis'
# data = 'dataframe'
# hue = 'column_for_hue'
# hue_order = ['1', '2'] # Takes in a list of values and will set the order of the values in the plot accordingly
# pallete = hue_colors # hue_colors = {"Yes":"Red", "No":"Black"} Takes in a dictionary which should map the variable values to the colors you want to represent the value.
#
# `relplot()` parameters
# sns.relplot
# (
#     x = 'column_on_x_axis'
#     y = 'column_on_y_axis'
#     data = 'dataframe'
#     kind = 'scatter | line'
#     col = 'categorical_column' # separate scatter plot for category 1 and category 2 as columns
#     row = 'categorical_column' # separate scatter plot for category 1 and category 2 as rows
#     col_wrap = 2 # two plots per row
#     col_order | row_order = ['Item1','Item2','Item3'] # change the order of the subplots. give it a list of ordered values.
#     size = 'column_for_size'
#     hue = 'column_for_hue'
#     style = 'column_for_style' # will use different point styles for each value of the variable.
#     alpha = '0.4' # value between 0 and 1 will vary the transparency of the points in the plot, with 0 being completely transparent and 1 being completely non-transparent.
#     markers = True
#     dashes =  False
#     errorbar = 'sd' # To see how varied the measurements are. The shaded area represents standard deviation, which shows the spread of the distribution of observations at each x value. ['ci', 'pi', 'se', 'sd']
#
# )
#
# ```

# %% [markdown]
# ```python
# `catplot()` parameters
# x     = 'categorical_column'
# y     = 'quantitative_column'
# data  = dataset
# kind  = 'box | count | point'
# order = ['cat1','cat2'] # change the order of the categories
# showfliers=False # Omit the outliers from your plot altogether.
# whis = '2.0 | [5, 95] | [0, 100]'
# # In Boxplot by default, whiskers extend to 1.5 * the IQR
# # Make them extend to 2.0 * IQR: `whis=2.0`
# # Show 5th and 95th percentile: `whis=[5, 95]`
# # Show min and max values: `whis=[0, 100]`
# estimator = median # To have the points and confidence intervals be calculated for the median instead of the mean, import the median function from the numpy library and set "estimator" equal to the numpy median function. (robust to outliers)
# linestyle='none' #  to remove the lines connecting each point in a point plot, to compare within a category group and not between them.
# capsize = 0.2 #  Customize the way that the confidence intervals are displayed. To add “caps” to the end of the confidence intervals, set the “capsize” parameter equal to the desired width of the caps.
#
# ```

# %% [markdown]
# **1. Relational Plots**
#
# - **Scatter Plot**
#   - Each plot point is an independent observation.
# - **Line Plot**
#   - Each plot point represents the same "thing" typically tracked over time.
#   -   `Multiple observations per x-value`: If a line plot is given multiple observations per x-value, it will aggregate them into a single summary measure. By default, it will display the mean. `Seaborn` will automatically calculate a confidence interval for the mean, displayed by the shaded region.
#
# **2. Categorical plots**
#
# Count plots and bar plots are two types of visualizations that Seaborn calls "categorical plots". Categorical plots involve a categorical variable, which is a variable that consists of a fixed, typically small number of possible values, or categories. These types of plots are commonly used when you want to make comparisons between different groups.
# - Count Plot
# - Bar Plot
#   - Bar plots look similar to` sns.countplot()`, but instead of the count of observations in each category, `sns.barplot()` show the mean of a quantitative variable among observations in each category.
# - Box Plot
#   - A box plot shows the distribution of quantitative data. The colored box represents the 25th to 75th percentile, and the line in the middle of the box represents the median. The whiskers give a sense of the spread of the distribution, and the floating points represent outliers. Box plots are commonly used as a way to compare the distribution of a quantitative variable across different groups of a categorical variable.
#   - Seaborn has a `boxplot()` function. But using "catplot()" function makes it easy to create subplots using the "col" and "row" parameters.
# - Point Plot
#   - Point plots show the mean of a quantitative variable for the observations in each category, plotted as a single point.
#   - The vertical bars extending above and below the mean represent the 95% confidence intervals for that mean.
#
# Line plots vs. Point plots
# - Show the mean of a quantitative variable and 95% confidence intervals for the mean.
# - Key difference:
#   - Line plots are relational plots, so both the x- and y-axis are quantitative variables.
#   - In a Point plot, one axis - usually the x-axis - is a categorical variable, making it a categorical plot.
#
# Point plots vs. Bar plots
# - For each category, both show the mean of a quantitative variable and the confidence intervals for those means.
# -

# %% [markdown]
# **1. Styling and color**
# - `sns.set_style()`
#   - Preset options: white, dark, whitegrid, darkgrid, ticks
# - `sns.set_pallete()`
#   - Diverging pallets: 'RdBu', 'PRGn', 'RdBu_r', 'PRGn_r'
#   - Sequential pallets: 'Greys', 'Blues', 'Purples','PuRd', 'GnBu'
#   - Custom pallets
# - `sns.set_context()`
#   - Smallest to largest: 'paper', 'notebook', 'talk', 'poster'
#   -
# **2. Titles and Labels**
#
# **Plot Objects:** FacetGrid vs. AxesSubplot objects
#
# | Feature       | FacetGrid | AxesSubplot |
# |--------------|----------|-------------|
# | **Functions that return it** | `relplot()`, `catplot()` | `scatterplot()`, `countplot()` |
# | **Number of plots** | Can create subplots (multiple plots) | Only creates a single plot |
# | **Used for** | Creating complex, multi-faceted visualizations | Simple individual plots |
# | **Customization** | Can map multiple plots using `.map()` | Directly modified using Matplotlib functions |
# | **Example** | `g = sns.catplot(x="day", y="total_bill", col="sex", data=tips)` | `sns.scatterplot(x="total_bill", y="tip", data=tips)` |
# | **Syntax**  | `g.fig.suptitle("Title", y=1.03)` | `g.set_title("New Title", y = 1.03)`|
# | **x and y labels** | `g.set(xlabel = "x label", ylabel = "y label") `|  `g.set(xlabel = "x label", ylabel = "y label")`  |

# %% [markdown]
# ## Introduction to Seaborn

# %%
# Reading datasets used in this jupyter notebook into pandas dataframes
countries_of_world = pd.read_csv('../data/data-viz-datasets/countries-of-the-world.csv')
survey_responses = pd.read_csv("../data/data-viz-datasets/young-people-survey-responses.csv")
austin_weather = pd.read_csv("../data/data-viz-datasets/austin_weather.csv")
climate_change = pd.read_csv("../data/data-viz-datasets/climate_change.csv")
medals = pd.read_csv("../data/data-viz-datasets/medals_by_country_2016.csv")
mpg = pd.read_csv("../data/data-viz-datasets/mpg.csv")
seattle_weather = pd.read_csv("../data/data-viz-datasets/seattle_weather.csv")
student_alchohol_consumption = pd.read_csv("../data/data-viz-datasets/student-alcohol-consumption.csv")
summer2016 = pd.read_csv("../data/data-viz-datasets/summer2016.csv")

# %%
sns.set_context("paper")

# %%
countries_of_world.head(5)
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
countries_of_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
# Converting GDP ($ per capita), Literacy (%) and Phones (per 1000) into a list
gdp = countries_of_world['GDP ($ per capita)'].to_list()

# %%
# Literacy (%) column should be a float datatype
countries_of_world["Literacy (%)"] = (
    countries_of_world["Literacy (%)"]
    .astype(str)  # Convert to string to handle any unexpected types
    .str.replace(",", ".")  # Replace "," with "." (if needed)
    .astype(float)  # Convert to float
)

# %%
# Phones (per 1000) column should be a float datatype
countries_of_world["Phones (per 1000)"] = (
    countries_of_world["Phones (per 1000)"]
    .astype(str)  # Convert to string to handle any unexpected types
    .str.replace(",", ".")  # Replace "," with "." (if needed)
    .astype(float)  # Convert to float
)

# %%
phones = countries_of_world['Phones (per 1000)'].tolist()
percent_literate = countries_of_world['Literacy (%)'].tolist()

# %%
# Create scatter plot with GDP on the x-axis and number of phones on the y-axis
sns.scatterplot(x=gdp, y=phones)
plt.show()

# %%
# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)
# Show plot
plt.show()

# %% [markdown]
# While this plot does not show a linear relationship between GDP and percent literate, countries with a lower GDP do seem more likely to have a lower percent of the population that can read and write.

# %%
# Create count plot with region on the y-axis
sns.countplot(y=countries_of_world["Region"])  # Correct way to reference the column
# Show plot
plt.show()

# %%
# Responses to a survey sent out to young people. Primary question was: how many young people surveyed report being scared of spiders? 
# Survey participants were asked to agree or disagree with the statement "I am afraid of spiders". 
# Responses vary from 1 to 5, where 1 is "Strongly disagree" and 5 is "Strongly agree".

# Create a count plot with "Spiders" on the x-axis
sns.countplot(x="Spiders", data=survey_responses)

# Display the plot
plt.show()

# %%
# Create a scatter plot of absences vs. final grade
sns.scatterplot(x="absences", y="G3", 
                data=student_alchohol_consumption, 
                hue="location",
                hue_order = ['Rural', 'Urban'])

# Show plot
plt.show()

# %% [markdown]
# It looks like students with higher absences tend to have lower grades in both rural and urban areas.

# %%
# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "green", "Urban": "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x='school', data=student_alchohol_consumption, hue='location', palette=palette_colors)

# Display plot
plt.show()

# %% [markdown]
# Students at GP tend to come from an urban location, but students at MS are more evenly split.

# %%
# Loading the tips dataset from seaborn

tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
hue_colors = {'Yes':'Black', 'No':'Red'}
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', palette=hue_colors)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Visualizing Two Quantitative Variables

# %%
# Using relplot for scatter plot to arrange the plots in rows/columns and separate charts
sns.relplot(x="absences", y="G3", 
            data=student_alchohol_consumption,
            kind="scatter", 
            col="study_time")

# Show plot
plt.show()

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_alchohol_consumption,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row='famsup',
            row_order=["yes", "no"])

# Show plot
plt.show()

# %% [markdown]
# It looks like the first semester grade does correlate with the final grade, regardless of what kind of support the student received.

# %% [markdown]
# Seaborn's mpg dataset, which contains one row per car model and includes information such as the year the car was made, the number of miles per gallon ("M.P.G.") it achieves, the power of its engine (measured in "horsepower"), and its country of origin.
#
# - What is the relationship between the power of a car's engine ("horsepower") and its fuel efficiency ("mpg")?
# - And how does this relationship vary by the number of cylinders ("cylinders") the car has?

# %%
mpg = sns.load_dataset('mpg')
mpg.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower",
            y="mpg", 
            data=mpg,
            kind="scatter", 
            size="cylinders",
            hue='cylinders')

# Show plot
plt.show()

# %% [markdown]
# Cars with higher horsepower tend to get a lower number of miles per gallon. They also tend to have a higher number of cylinders.

# %%
# Create a scatter plot of acceleration vs. mpg
sns.relplot(kind='scatter',data=mpg,x='acceleration',y='mpg',hue='origin',style='origin')
# Show plot
plt.show()

# %% [markdown]
# Cars from the USA tend to accelerate more quickly and get lower miles per gallon compared to cars from Europe and Japan.

# %%
# How has the average miles per gallon achieved by these cars changed over time?

# Create line plot
sns.relplot(data=mpg, x='model_year', y='mpg', kind='line')
# Show plot
plt.show()

# %% [markdown]
# - The average miles per gallon has generally increased over time.
# - The 95% confidence interval for average miles per gallon in 1970 is approximately 16 - 19.5 miles per gallon.
# - This plot assumes that our data is a random sample of all cars in the US, Europe, and Japan.

# %%
# Make the shaded area show the standard deviation
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line", ci='sd')

# Show plot
plt.show()
# Out:
# /Users/rashmishreeveeraiah/Documents/GitHub/data-science-python/.venv-py-datascience/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# This plot shows us the distribution of miles per gallon for all the cars in each year.

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            errorbar=None, style="origin", 
            hue="origin",
            markers=True,
            dashes=False)

# Show plot
plt.show()

# %% [markdown]
# Downward trend in horsepower was more pronounced among cars from the USA.

# %% [markdown]
# ## Visualizing a Categorical and a Quantitative Variable

# %%
survey_responses.columns
# Out:
# Index(['Unnamed: 0', 'Music', 'Techno', 'Movies', 'History', 'Mathematics',
#        'Pets', 'Spiders', 'Loneliness', 'Parents' advice', 'Internet usage',
#        'Finances', 'Age', 'Siblings', 'Gender', 'Village - town'],
#       dtype='object')

# %%
survey_responses['Age Category'] = survey_responses['Age'].apply(lambda x: 'Less than 21' if x < 21 else '21+')

# %%
# Suspicion is that young people spend a lot of time on the internet, but how much do they report using the internet each day?
sns.catplot(y="Internet usage", data=survey_responses,
            kind="count",
            col='Age Category')
# Show plot
plt.show()

# %% [markdown]
# Most young people use the internet for a few hours every day, regardless of their age.

# %%
sns.catplot(data=survey_responses, kind='bar', x='Gender', y='Mathematics')


# Show plot
plt.show()

# %% [markdown]
# When the y-variable is True/False, bar plots will show the percentage of responses reporting True. This plot shows us that males report a much higher interest in math compared to females.

# %% [markdown]
# *The "`study_time`" variable records each student's reported weekly study time as one of the following categories: "<2 hours", "2 to 5 hours", "5 to 10 hours", or ">10 hours". Do students who report higher amounts of studying tend to get better final grades?*

# %%
# List of categories from lowest to highest
category_order = ["<2 hours", 
                  "2 to 5 hours", 
                  "5 to 10 hours", 
                  ">10 hours"]

# Turn off the confidence intervals
sns.catplot(x="study_time", y="G3",
            data=student_alchohol_consumption,
            kind="bar",
            order=category_order,
            errorbar = None)

# Show plot
plt.show()

# %% [markdown]
# Students in the sample who studied more have a slightly higher average grade, but it's not a strong relationship.

# %%
# Create a box plot with subgroups and omit the outliers
sns.catplot(data=student_alchohol_consumption, kind='box', x='internet', y='G3', hue='location', showfliers=False)

# Show plot
plt.show()

# %% [markdown]
# The median grades are quite similar between each group, but the spread of the distribution looks larger among students who have internet access.

# %% [markdown]
# *Compare the distribution of final grades ("G3") between students who are in a romantic relationship and those that are not. We'll use the "romantic" variable, which is a yes/no indicator of whether the student is in a romantic relationship.*

# %%
# Set the whiskers at the min and max values
sns.catplot(x="romantic", y="G3",
            data=student_alchohol_consumption,
            kind="box",
            whis=[0, 100])
sns.set_context("poster")
# Show plot
plt.show()

# %%
# Set the whiskers at the 5 and 95th percentile
sns.catplot(x="romantic", y="G3",
            data=student_alchohol_consumption,
            kind="box",
            whis=[5, 95])
#sns.set_context("poster")
# Show plot
plt.show()

# %% [markdown]
# The median grade is the same between these two groups, but the max grade is higher among students who are not in a romantic relationship.

# %% [markdown]
# *Does the quality of the student's family relationship influence the number of absences the student has in school?*
#
# *The `"famrel"` variable describes the quality of a student's family relationship from 1 (very bad) to 5 (very good).*

# %%
# Create a point plot of family relationship vs. absences
sns.catplot(data=student_alchohol_consumption, kind='point', x='famrel', y='absences')
# Show plot
plt.show()

# %%
# Add caps to the confidence interval
sns.catplot(x="famrel", y="absences",
			data=student_alchohol_consumption,
            kind="point",
            capsize = 0.2)
        
# Show plot
plt.show()

# %%
# Remove the lines joining the points
sns.catplot(x="famrel", y="absences",
			data=student_alchohol_consumption,
            kind="point",
            capsize=0.2,
            linestyle='none')
            
# Show plot
plt.show()

# %% [markdown]
# While the average number of absences is slightly smaller among students with higher-quality family relationships, the large confidence intervals tell us that we can't be sure there is an actual association here.

# %%
# Import median function from numpy
from numpy import median

# Plot the median number of absences instead of the mean
sns.catplot(x="romantic", y="absences",
			data=student_alchohol_consumption,
            kind="point",
            hue="school",
            ci=None,
            estimator=median)
sns.set_context('poster')

# Show plot
plt.show()
# Out:
# /var/folders/jn/9nlkdx3s70bfdjtw_1q5jnvm0000gn/T/ipykernel_24106/2455990729.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="romantic", y="absences",

# %% [markdown]
# It looks like students in romantic relationships have a higher average and median number of absences in the GP school, but this association does not hold for the MS school.

# %% [markdown]
# ## Customizing Seaborn Plots

# %%
# Create a mapping dictionary
value_map = {
    1: 'Never',
    2: 'Rarely',
    3: 'Sometimes',
    4: 'Often',
    5: 'Always'
}

# Use the .map() method to replace the values
survey_responses['Parents\' advice'] = survey_responses['Parents\' advice'].map(value_map)

# %%
survey_responses['Parents\' advice'].value_counts()
# Out:
# Parents' advice
# Sometimes    455
# Often        344
# Rarely       118
# Always        56
# Never         35
# Name: count, dtype: int64

# %%
# Change the color palette to "RdBu"
sns.set_style("whitegrid")
sns.set_palette("Blues")
sns.set_context('paper')

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes", 
                  "Often", "Always"]

sns.catplot(x="Parents\' advice", 
            data=survey_responses, 
            kind="count", 
            order=category_order)

# Show plot
plt.show()

# %%
# Change the context to "paper"
sns.set_context("paper")

# Create bar plot
sns.catplot(x="Siblings", y="Loneliness",
            data=survey_responses, kind="bar")

# Show plot
plt.show()

# %%
# Set the style to "darkgrid"
sns.set_style('darkgrid')

# Set a custom color palette
sns.set_palette(["#39A7D0","#36ADA4"])

# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age", 
            data=survey_responses, kind="box")

# Show plot
plt.show()

# %% [markdown]
# It looks like the median age is the same for males and females, but distribution of females skews younger than the males

# %% [markdown]
# FacetGrid Object type

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# AxisSubplot type

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg", 
                 data=mpg,
                 hue="origin",
                 estimator='mean',
                 errorbar=None)

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")
# Add x-axis and y-axis labels
g.set(xlabel="Car Model Year", ylabel="Average MPG")


# Show plot
plt.show()

# %% [markdown]
# The average miles per gallon achieved is increasing over time for all three places of origin, but the USA is always lower than Europe and Japan.

# %%
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)


# Show plot
plt.show()
# Out:
# /var/folders/jn/9nlkdx3s70bfdjtw_1q5jnvm0000gn/T/ipykernel_24106/1943810201.py:2: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.catplot(x="origin",

# %% [markdown]
# Since higher values indicate slower acceleration, it looks like cars from Japan and Europe have significantly slower acceleration compared to the USA.

# %% [markdown]
# One of the questions asked in the Survey is "Are you interested in having pets?"
#
# Let's explore whether the distribution of ages of those answering "yes" tends to be higher or lower than those answering "no", controlling for gender.

# %%
# Set palette to "Blues"
sns.set_palette("Blues")

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_responses, 
                kind="box", hue="Pets")

# Set title to "Age of Those Interested in Pets vs. Not"
g.fig.suptitle("Age of Those Interested in Pets vs. Not")

# Show plot
plt.show()

# %% [markdown]
# After controlling for gender, it looks like the age distributions of people who are interested in pets are similar than those who aren't.

# %%
# Set the figure style to "dark"
sns.set_style("dark")

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Techno", 
                data=survey_responses, kind="bar",
                col="Gender")

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence", 
       ylabel="% Who Like Techno")

# Show plot
plt.show()
